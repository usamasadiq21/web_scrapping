# %% [markdown]
# ### <center>Request Library</center>

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %% [markdown]
# 1. GET Method

# %%
uri = "https://api.github.com"
response = requests.get(uri)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_s
# ...

# %% [markdown]
# - 1.1 Passing "Query Parameters" To filter data.
#   - use Query parameters in GET message
#   - search for all repositories that ocntain the word requests and the main language is Python.
#   - GitHub repositories search API: https://api.github.com/search/repositories

# %%
uri2 = "https://api.github.com/search/repositories"

# %%
params = {"q": "requests+language:python"}

# %%
response = requests.get(uri2, params=params)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"total_count":248,"incomplete_results":false,"items":[{"id":33210074,"node_id":"MDEwOlJlcG9zaXRvcnkzMzIxMDA3NA==","name":"secrules-language-evaluation","full_name":"SpiderLabs/secrules-language-evaluation","private":false,"owner":{"login":"SpiderLabs","id":508521,"node_id":"MDEyOk9yZ2FuaXphdGlvbjUwODUyMQ==","avatar_url":"https://avatars.githubusercontent.com/u/508521?v=4","gravatar_id":"","url":"https://api.github.com/users/SpiderLabs","html_url":"https://github.com/SpiderLabs","followers_url":"https://api.github.com/users/SpiderLabs/followers","following_url":"https://api.github.com/users/SpiderLabs/following{/other_user}","gists_url":"https://api.github.com/users/SpiderLabs/gists{/gist_id}","starred_url":"https://api.github.com/users/SpiderLabs/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/SpiderLabs/subscriptions","organizations_url":"https://api.github.com/users/SpiderLabs/orgs","repos_url":"https://api.github.com/users/SpiderLabs/repos","events_url
# ...

# %% [markdown]
# 2. POST Method

# %% [markdown]
# - send some data to server.
# - server usually understand json format.
# - server address: "https://httpbin.org/post"
# - By default whatever the data we sent using POST method of the request library fall in the form key, means we can retrieve our data using "response.json()["form"].

# %%
post_uri = "https://httpbin.org/post"

# %%
data_to_post = {
    "username" : "usama",
    "password": "778834"
}

# %%
# This will post data in form-urlencoded format ni in json format.
response = requests.post(post_uri, data=data_to_post)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': '778834', 'username': 'usama'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '30',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d9aae2-07f4e9c926bc22174804772d'},
#  'json': None,
#  'origin': '110.38.243.132',
#  'url': 'https://httpbin.org/post'}

# %%
response.status_code
# Out:
# 200

# %%
# our posted data is now available in "form" key, and "JSON" key is empty, because to POST data we use "data" params.  
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': '778834', 'username': 'usama'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '30',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d9aae2-07f4e9c926bc22174804772d'},
#  'json': None,
#  'origin': '110.38.243.132',
#  'url': 'https://httpbin.org/post'}

# %%
# Retrieve posted data. 
response.json()["form"]
# Out:
# {'password': '778834', 'username': 'usama'}

# %%
# To post data in json format.
json_response = requests.post(post_uri, json=data_to_post)

# %%
json_response.status_code
# Out:
# 200

# %%
# Now in below output we have "form" key is empty and out data is available in "json" key, because to POST data we use "json" params.
json_response.json()
# Out:
# {'args': {},
#  'data': '{"username": "usama", "password": "778834"}',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '43',
#   'Content-Type': 'application/json',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d9aae3-4247185037acc0c84af930ea'},
#  'json': {'password': '778834', 'username': 'usama'},
#  'origin': '110.38.243.132',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# 3. PUT Method (updating data)

# %%
# Previously POST data in "form" Key.
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': '778834', 'username': 'usama'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '30',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d9aae2-07f4e9c926bc22174804772d'},
#  'json': None,
#  'origin': '110.38.243.132',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# - updating above mention data in the "form" key

# %%
put_uri = "https://httpbin.org/put"

# %%
put_data = {
    "username": "saad",
    "email": "saad@gmail.com"
}

# %%
put_response = requests.put(put_uri, data=put_data)

# %%
# Data is now updated in the "form" key.
put_response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'email': 'saad@gmail.com', 'username': 'saad'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '36',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d9aae6-0e70ca7f6558bbd73ab2edad'},
#  'json': None,
#  'origin': '110.38.243.132',
#  'url': 'https://httpbin.org/put'}

# %% [markdown]
# - Delete Method

# %%
delete_uri = "https://httpbin.org/delete" 

# Deleting the updated Data
delete_data = requests.delete(delete_uri)

# %%
delete_data.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d9aae9-6da0772705fcaf1d35886c1b'},
#  'json': None,
#  'origin': '110.38.243.132',
#  'url': 'https://httpbin.org/delete'}

# %% [markdown]
# ### <center> Working with Public API</center>
# - API: https://jsonplaceholder.typicode.com/
# - endpoint: posts

# %%
json_placeholder_API = "https://jsonplaceholder.typicode.com/posts"

# %% [markdown]
# 1. Make A GET request to retrieve some posts.

# %%
try:
    response = requests.get(json_placeholder_API)
    response.raise_for_status()
except Exception as e:
    print(e)
else: 
    status_code = response.status_code
    print(f'Status Code: {status_code}')
    if status_code == 200:
        print('Successful Get Request')
        posts = response.json()
        for i in range(3):
            print(f'Post {i + 1}:')
            print(posts[i])
    
    else:
        print("Unsuccessful GET Request")
# Out:
# Status Code: 200
# Successful Get Request
# Post 1:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}
# Post 2:
# {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}
# Post 3:
# {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}

# %% [markdown]
# 1. Make a POST request to submit a post.

# %%
# Below data is to make a POST req using json_placeholder API
new_post = {
    "title": "Sample Post",
    "body": "This is a sample post",
    "userId": 2001
}

# %%
try:
    post_response = requests.post(json_placeholder_API, data=new_post)
    # post_response.raise_for_status()
except Exception as e:
    print(e)
else:

    if post_status == 201:
        print(f"Status Code: {post_status}.")
        print('Successful POST Req.')
        post = post_response.json()
        print("Post")
        print(post)

    else:
        print(f"Status Code: {status_code}.")
        print('Unsuccessful POST Req.')
# Out:
# Status Code: 201.
# Successful POST Req.
# Post
# {'title': 'Sample Post', 'body': 'This is a sample post', 'userId': '2001', 'id': 101}
